# %% [markdown]
# ---
# title: "Large Soil Spectral Library"
# description: "How to leverage a large soil spectral library to improve soil classification"
# author: "Franck Albinet"
# date: "2024-01-15"
# categories: [soil-spectroscopy, machine-learning]
# ---

# %% [markdown]
# # Introduction

# %% [markdown]
# This is a ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('A Simple Sine Wave')
plt.show()
